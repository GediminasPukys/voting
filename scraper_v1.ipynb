# %%
from bs4 import BeautifulSoup
import requests

# URL of the webpage containing the XML data
url_seimo_kadencijos = 'https://apps.lrs.lt/sip/p2b.ad_seimo_kadencijos'
url_seimo_posedziai = 'https://apps.lrs.lt/sip/p2b.ad_seimo_posedziai?sesijos_id=127'
url_seimo_posedzio_eiga = 'https://apps.lrs.lt/sip/p2b.ad_sp_eiga?posedzio_id=-501747'
url_balsavimo_rezultatai = 'https://apps.lrs.lt/sip/p2b.ad_sp_balsavimo_rezultatai?balsavimo_id=-43782'

# All URLs together
urls = [url_seimo_kadencijos, url_seimo_posedziai, url_seimo_posedzio_eiga, url_balsavimo_rezultatai]

# List of scraped data
scraped_data = []

# Scraping...
for url in urls:

    # Send a GET request to fetch the webpage content
    response = requests.get(url)

    # Parse the XML data using BeautifulSoup
    soup = BeautifulSoup(response.content, 'xml')

    # Find all nodes and subnodes
    all_nodes = soup.find_all(recursive=True)
    
    # Read names and attributes of all nodes, put into dictionaries
    for node in all_nodes:
        d = {**{'tag': node.name}, **(node.attrs)}
        scraped_data += [d]

# Output
print(scraped_data)
# Out:
# [{'tag': 'SeimoInformacija', 'pavadinimas': 'Seimo kadencijos', 'suformavimo_laikas': '2024-02-28 09:38:46', 'šaltinis': 'www.lrs.lt', 'tiekėjas': 'Seimo kanceliarija', 'licencija': 'CC BY 4.0'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '1', 'pavadinimas': '1990–1992 metų kadencija', 'data_nuo': '1990-03-10', 'data_iki': '1992-11-22'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '2', 'pavadinimas': '1992–1996 metų kadencija', 'data_nuo': '1992-11-24', 'data_iki': '1996-11-22'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '3', 'pavadinimas': '1996–2000 metų kadencija', 'data_nuo': '1996-11-25', 'data_iki': '2000-10-18'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '4', 'pavadinimas': '2000–2004 metų kadencija', 'data_nuo': '2000-10-19', 'data_iki': '2004-11-14'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '5', 'pavadinimas': '2004–2008 metų kadencija', 'data_nuo': '2004-11-15', 'data_iki': '2008-11-16'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '6', 'pavadinimas': '2008–2012 metų kadencija', 'data_nuo': '2008-11-17', 'data_iki': '2012-11-16'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '7', 'pavadinimas': '2012–2016 metų kadencija', 'data_nuo': '2012-11-16', 'data_iki': '2016-11-14'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '8', 'pavadinimas': '2016–2020 metų kadencija', 'data_nuo': '2016-11-14', 'data_iki': '2020-11-13'}, {'tag': 'SeimoKadencija', 'kadencijos_id': '9', 'pavadinimas': '2020–2024 metų kadencija', 'data_nuo': '2020-11-13', 'data_iki': ''}, {'tag': 'SeimoInformacija', 'pavadinimas': 'Seimo posėdžiai', 'suformavimo_laikas': '2024-02-28 09:38:47', 'šaltinis': 'www.lrs.lt', 'tiekėjas': 'Seimo kance